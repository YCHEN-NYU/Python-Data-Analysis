# %%
# Play with the scikit-learn machine learning example
from sklearn import datasets
iris = datasets.load_iris()
digits = datasets.load_digits()

# %%
# Grab the digit datasets and plot out some examples
import matplotlib.pyplot as plt
import numpy as np
print(digits['data'].shape)
print(digits['images'].shape)

fig = plt.figure()
N = 4
f, ax = plt.subplots(N, N, sharex=True, sharey=True, figsize=(N, N))
for i in range(N):
    for j in range(N):
#         ax[i, j].imshow(digits['images'][i*N + j%N + 1,:, :], interpolation='bicubic', aspect=1)
        ax[i, j].imshow(digits['images'][i*N + j%N,:, :])

plt.subplots_adjust(wspace=0.05, hspace=0.05)
plt.show()
# Out:
# (1797, 64)
# (1797, 8, 8)

# %%
# Play with the scikit-learn machine learning example
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets
from sklearn import svm 

digits = datasets.load_digits()
fig = plt.figure()
N = 12

plt.imshow(digits['images'][-N,:,:])
plt.show()
clf = svm.SVC(gamma=0.001, C=100)
clf.fit(digits['data'][:-N], digits['target'][:-N])
print(clf.predict(digits.data[-N:-N+1]))
# Out:
# [7]

# %% [markdown]
# ## Sigmoid
# ### $$ f(x) = \frac{1}{1+e^{-x}}$$

# %%
import numpy as np
import matplotlib.pyplot as plt
def sigmoid(x):
    return 1/(1+np.exp(-x))
def sigmoid_prime(x):
    return sigmoid(x)*(1-sigmoid(x))
x = np.linspace(-10, 10, 101)
y = sigmoid(x)
dydx = sigmoid_prime(x)
fig = plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
fx, = plt.plot(x, y, label='$sigmoid(x)$')
plt.legend(handles=[fx])

plt.subplot(1, 2, 2)
fxdx, = plt.plot(x, dydx, 'm--', label='$sigmoid\'(x)$')
plt.legend(handles=[fxdx])
plt.show()
